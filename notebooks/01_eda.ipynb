# %%
import pandas as pd

df=pd.read_csv(
    "../data/GSE2034_series_matrix.txt.gz",
    sep='\t',
    comment='!',
    index_col=0,
    compression='gzip'
)
print(df.shape)
df.head()
# Out:
# (22283, 286)
#            GSM36777  GSM36778  GSM36779  GSM36780  GSM36781  GSM36782  \
# ID_REF
# 1007_s_at    3848.1    6520.9    5285.7    4043.7    4263.6    2949.8
# 1053_at       228.9     112.5     178.4     398.7     417.7     221.2
# 117_at        213.1     189.8     269.7     312.4     327.1     225.0
# 121_at       1009.4    2083.3    1203.4    1104.4    1043.3    1117.6
# 1255_g_at      31.8     145.8      42.5     108.2      69.2      47.4
#
#            GSM36783  GSM36784  GSM36785  GSM36786  ...  GSM37053  GSM37054  \
# ID_REF                                             ...
# 1007_s_at    5498.9    3863.1    3370.4    3991.9  ...    4058.2    4017.6
# 1053_at       280.4     198.2     304.7     198.2  ...     183.4     356.1
# 117_at        243.5     244.4     348.5     185.3  ...     326.6     234.9
# 121_at       1085.4    1423.1    1196.4     993.3  ...    1041.3    1195.6
# 1255_g_at      84.3     102.0      22.8      86.3  ...     143.5      32.7
#
#            GSM37055  GSM37056  GSM37057  GSM37058  GSM37059  GSM37060  \
# ID_REF
# 1007_s_at    2841.0    2914.2    3681.0    3066.9    2773.0    2984.3
# 1053_at       234.6     169.4      94.5     265.5     209.8     160.0
# 117_at        369.6     149.5     236.4     347.9     226.7     252.9
# 121_at        751.5    1117.8    1022.4    1127.4    1071.8    1178.5
# 1255_g_at      62.6      43.0     100.5      47.0      45.1     146.3
#
#            GSM37061  GSM37062
# ID_REF
# 1007_s_at    3540.0    2620.0
# 1053_at       285.7     180.5
# 117_at        135.1     191.8
# 121_at       1256.7    1284.6
# 1255_g_at      75.9      87.4
#
# [5 rows x 286 columns]

# %%
df_t=df.T
print(df_t.shape)
df_t.head()
# Out:
# (286, 22283)
# ID_REF    1007_s_at  1053_at  117_at  121_at  1255_g_at  1294_at  1316_at  \
# GSM36777     3848.1    228.9   213.1  1009.4       31.8    551.5    176.7
# GSM36778     6520.9    112.5   189.8  2083.3      145.8    802.8    278.4
# GSM36779     5285.7    178.4   269.7  1203.4       42.5    557.5    183.3
# GSM36780     4043.7    398.7   312.4  1104.4      108.2    568.5    187.7
# GSM36781     4263.6    417.7   327.1  1043.3       69.2    653.2    185.8
#
# ID_REF    1320_at  1405_i_at  1431_at  ...  AFFX-r2-Hs28SrRNA-5_at  \
# GSM36777     11.9      309.3     49.9  ...                   619.9
# GSM36778     28.3      449.0    122.9  ...                   511.3
# GSM36779     56.4      101.9     85.9  ...                  1618.4
# GSM36780     42.1      899.1     90.7  ...                   780.5
# GSM36781     21.8     3629.3     96.0  ...                   276.0
#
# ID_REF    AFFX-r2-Hs28SrRNA-M_at  AFFX-r2-P1-cre-3_at  AFFX-r2-P1-cre-5_at  \
# GSM36777                   661.5              33168.9              25644.4
# GSM36778                   716.1              54401.4              40720.0
# GSM36779                  1189.3              61244.1              50878.7
# GSM36780                   801.1              62292.1              46870.8
# GSM36781                   191.1              57295.1              40847.1
#
# ID_REF    AFFX-ThrX-3_at  AFFX-ThrX-5_at  AFFX-ThrX-M_at  AFFX-TrpnX-3_at  \
# GSM36777            11.1             9.2            25.0              4.2
# GSM36778            17.1            62.0            21.4              9.3
# GSM36779             6.4             8.4             7.4              7.1
# GSM36780            13.5            10.8            16.0              4.6
# GSM36781            19.8            30.5            22.1              7.3
#
# ID_REF    AFFX-TrpnX-5_at  AFFX-TrpnX-M_at
# GSM36777              7.0             10.0
# GSM36778             11.2             15.7
# GSM36779             64.0              4.1
# GSM36780             12.2              7.3
# GSM36781              5.5             11.6
#
# [5 rows x 22283 columns]

# %%
import gzip
from io import StringIO

with gzip.open("../data/GPL96.annot.gz", 'rt') as f:
    lines = f.readlines()

# Find the line that says the real table starts, and where it ends
start = next(i for i, l in enumerate(lines) if l.startswith('!platform_table_begin')) + 1
end = next(i for i, l in enumerate(lines) if l.startswith('!platform_table_end'))

table_text = ''.join(lines[start:end])
annot = pd.read_csv(StringIO(table_text), sep='\t', low_memory=False)

print(annot.shape)
annot.head()
# Out:
# (22283, 21)
#           ID                                         Gene title  \
# 0  1007_s_at  microRNA 4640///discoidin domain receptor tyro...
# 1    1053_at                     replication factor C subunit 2
# 2     117_at       heat shock protein family A (Hsp70) member 6
# 3     121_at                                       paired box 8
# 4  1255_g_at                     guanylate cyclase activator 1A
#
#       Gene symbol          Gene ID UniGene title UniGene symbol UniGene ID  \
# 0  MIR4640///DDR1  100616237///780           NaN            NaN        NaN
# 1            RFC2             5982           NaN            NaN        NaN
# 2           HSPA6             3310           NaN            NaN        NaN
# 3            PAX8             7849           NaN            NaN        NaN
# 4          GUCA1A             2978           NaN            NaN        NaN
#
#                                     Nucleotide Title         GI  \
# 0  Human receptor tyrosine kinase DDR gene, compl...  1753221.0
# 1  Human replication factor C, 40-kDa subunit (A1...  1590810.0
# 2              Human heat-shock protein HSP70B' gene    35221.0
# 3                                H.sapiens Pax8 mRNA    38425.0
# 4  Homo sapiens guanylate cyclase activating prot...   623404.0
#
#   GenBank Accession  ...  Platform_ORF  Platform_SPOTID Chromosome location  \
# 0            U48705  ...           NaN              NaN              6p21.3
# 1            M87338  ...           NaN              NaN             7q11.23
# 2            X51757  ...           NaN              NaN                1q23
# 3            X69699  ...           NaN              NaN                2q13
# 4            L36861  ...           NaN              NaN              6p21.1
#
#                                Chromosome annotation  \
# 0  Chromosome 6, NC_000006.12 (30890883..30890972...
# 1  Chromosome 7, NC_000007.14 (74231502..74254458...
# 2  Chromosome 1, NC_000001.11 (161524540..161526897)
# 3  Chromosome 2, NC_000002.12 (113215997..1132789...
# 4    Chromosome 6, NC_000006.12 (42155377..42180083)
#
#                                          GO:Function  \
# 0  ATP binding///collagen binding///collagen bind...
# 1  ATP binding///contributes_to DNA clamp loader ...
# 2  ATP binding///ATPase activity, coupled///enzym...
# 3  DNA binding///DNA binding///RNA polymerase II ...
# 4  calcium ion binding///calcium sensitive guanyl...
#
#                                           GO:Process  \
# 0  branching involved in mammary gland duct morph...
# 1  DNA damage response, detection of DNA damage//...
# 2  NOT cellular heat acclimation///cellular respo...
# 3  anatomical structure morphogenesis///branching...
# 4  cellular response to calcium ion///phototransd...
#
#                                         GO:Component  \
# 0  basolateral plasma membrane///extracellular ex...
# 1  Ctf18 RFC-like complex///DNA replication facto...
# 2  colocalizes_with COP9 signalosome///blood micr...
# 3                nucleoplasm///nucleoplasm///nucleus
# 4  photoreceptor disc membrane///photoreceptor in...
#
#                                       GO:Function ID  \
# 0  GO:0005524///GO:0005518///GO:0005518///GO:0046...
# 1  GO:0005524///contributes_to GO:0003689///GO:00...
# 2  GO:0005524///GO:0042623///GO:0019899///GO:0031...
# 3  GO:0003677///GO:0003677///GO:0000978///GO:0000...
# 4               GO:0005509///GO:0008048///GO:0030249
#
#                                        GO:Process ID  \
# 0  GO:0060444///GO:0007155///GO:0038063///GO:0038...
# 1  GO:0042769///GO:0006260///GO:0070987///GO:0042...
# 2  NOT GO:0070370///GO:0034605///GO:0034605///GO:...
# 3  GO:0009653///GO:0001658///GO:0071371///GO:0007...
# 4  GO:0071277///GO:0007602///GO:0031284///GO:0022...
#
#                                      GO:Component ID
# 0  GO:0016323///GO:0070062///GO:0005615///GO:0005...
# 1               GO:0031390///GO:0005663///GO:0005654
# 2  colocalizes_with GO:0008180///GO:0072562///GO:...
# 3               GO:0005654///GO:0005654///GO:0005634
# 4               GO:0097381///GO:0001917///GO:0005886
#
# [5 rows x 21 columns]

# %%
esr1_rows=annot[annot['Gene symbol']=='ESR1']
esr1_rows
# Out:
#                 ID           Gene title Gene symbol Gene ID UniGene title  \
# 4751     205225_at  estrogen receptor 1        ESR1    2099           NaN
# 10670  211233_x_at  estrogen receptor 1        ESR1    2099           NaN
# 10671  211234_x_at  estrogen receptor 1        ESR1    2099           NaN
# 10672  211235_s_at  estrogen receptor 1        ESR1    2099           NaN
# 11031  211627_x_at  estrogen receptor 1        ESR1    2099           NaN
# 14923    215551_at  estrogen receptor 1        ESR1    2099           NaN
# 14924  215552_s_at  estrogen receptor 1        ESR1    2099           NaN
# 16529    217163_at  estrogen receptor 1        ESR1    2099           NaN
# 16556  217190_x_at  estrogen receptor 1        ESR1    2099           NaN
#
#       UniGene symbol UniGene ID  \
# 4751             NaN        NaN
# 10670            NaN        NaN
# 10671            NaN        NaN
# 10672            NaN        NaN
# 11031            NaN        NaN
# 14923            NaN        NaN
# 14924            NaN        NaN
# 16529            NaN        NaN
# 16556            NaN        NaN
